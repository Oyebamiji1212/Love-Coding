# %% [markdown]
# <a href="https://colab.research.google.com/github/Oyebamiji1212/Love-Coding/blob/main/My_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Student Performance Analyzer
Name = 'Oyebamiji Karimot Ifeoluwa'
Age = 30
Matric_number = '''25/67QK037'''
Department = 'Educational Management'

X = 82
Y = 89
Z = 92

Total_score = X + Y + Z
Average_score = Total_score / 3
Highest_score = X

if Y > Highest_score:
   Highest_score = Y
if Z > Highest_score:
   Highest_score = Z

Lowest_score = X

if Y < Lowest_score:
   Lowest_score = Y
if Z < Lowest_score:
   Lowest_score = Z

Pass = Average_score >= 50

print("Name:", Name)
print("Age:", Age)
print("Matric_number:", Matric_number)
print("Department:", Department)
print("Mathematics:", X)
print("Python:", Y)
print("Statistics:", Z)
print("Highest score:", Highest_score)
print("Lowest score:", Lowest_score)
print("Average score:", Average_score)

if Pass == True:
    print("Result: Pass")
else:
    print("Resul: Fail")
# Out:
# Name: Oyebamiji Karimot Ifeoluwa
# Age: 30
# Matric_number: 25/67QK037
# Department: Educational Management
# Mathematics: 82
# Python: 89
# Statistics: 92
# Highest score: 92
# Lowest score: 82
# Average score: 87.66666666666667
# Result: Pass
